# %% [markdown]
# # Region

# %%
Africa = {
    "AGO": "Angola",
    "BDI": "Burundi",
    "BEN": "Benin",
    "BFA": "Burkina Faso",
    "BWA": "Botswna",
    "CAF": "Central African Republic",
    "CIV": "Cote d'lvoire",
    "CMR": "Cameroon",
    "COD": "Congo, The Democratic Republic Of The",
    "COG": "Congo, The Democratic Republic Of The", #10
    "COM": "Comoros",
    "CPV": "Cape Verde",
    "DJI": "Djibouti",
    "DZA": "Algeria",
    "ERI": "Eritrea",
    "ESH": "Western Sahara",
    "ETH": "Ethiopia",
    "GAB": "Gabon",
    "GHA": "Ghana",
    "GIN": "Guinea", #20
    "GMB": "Gambia",
    "GNB": "Guinea-Bissau",
    "GNQ": "Equatorial-Guinea",
    "KEN": "Kenya",
    "LBR": "Liberia",
    "LBY": "Libya",
    "LSO": "Lesotho",
    "MAR": "Morocco",
    "MDG": "Madagascar",
    "MLI": "Mali", #30
    "MOZ": "Mozambique",
    "MRT": "Mauritania",
    "MUS": "Mauritius",
    "MWI": "Malawi",
    "NAM": "Namibia",
    "NER": "Niger",
    "NGA": "Nigeria",
    "REU": "Reunion",
    "RWA": "Rwanda",
    "SDN": "Sudan", #40
    "SEN": "Senegal",
    "SLE": "Sierra Leone",
    "SOM": "Somalia",
    "STP": "Sao Tome and Principe",
    "SWZ": "Swaziland",
    "TCD": "Chad",
    "TGO": "Togo",
    "TUN": "Tunisia",
    "TZA": "Tanzania",
    "UGA": "Uganda", #50
    "ZAF": "South Africa",
    "ZMB": "Zambia",
    "ZWE": "Zimbabwe" #53
}

China = {
    'CHN': 'China',
    'HKG': 'Hong Kong',
    'MAC': 'Macao',
    'TWN': 'Taiwan' #4
}

EU_27 = {
    'AUT': 'Austria',
    'BEL': 'Belgium',
    'BGR': 'Bulgaria',
    'CYP': 'Cyprus',
    'CZE': 'Czech Republic',
    'DEU': 'Germany',
    'DNK': 'Denmark',
    'ESP': 'Spain',
    'EST': 'Estonia',
    'FIN': 'Finland', #10
    'FRA': 'France',
    'GBR': 'United Kingdom',
    'GRC': 'Greece',
    'GRL': 'Greenland',
    'HRV': 'Croatia',
    'HUN': 'Hungary',
    'IRL': 'Ireland',
    'ITA': 'Italy',
    'LTU': 'Lithuania',
    'LUX': 'Luxembourg', #20
    'LVA': 'Latvia',
    'MLT': 'Malta',
    'NLD': 'Netherlands',
    'POL': 'Poland',
    'PRT': 'Portugal',
    'ROM': '', ## NA
    'ROU': 'Romania',
    'SVK': 'Slovak Republic',
    'SVN': 'Slovenia',
    'SWE': 'Sweden' #30
}

Middle_East = {
    'ARE': 'United Arab Amirates',
    'BHR': 'Bahrain',
    'EGY': 'Egypt',
    'IRN': 'Iran, Islamic Republic of',
    'IRQ': 'Iraq',
    'ISR': 'Israel',
    'JOR': 'Jordan',
    'KWT': 'Kuwait',
    'LBN': 'Lebanon',
    'OMN': 'Oman', #10
    'PSE': 'Palestine',
    'QAT': 'Qatar',
    'SAU': 'Saudi Arabia',
    'SYR': 'Syrian Arab Republic',
    'YEM': 'Yemen' #15
}

Non_EU_Europe = {
    'ALB': 'Albania',
    'AND': 'Andorra',
    'ARM': 'Armenia',
    'AZE': 'Azerbaijan',
    'BIH': 'Bosnia and Herzegovina',
    'BLR': 'Belarus',
    'CHE': 'Switzerland',
    'CHI': '', ## NA
    'FRO': 'Faroe Islands',
    'GEO': 'Georgia', #10
    'GIB': 'Gibraltar',
    'IMN': 'Isle of Man',
    'ISL': 'Iceland',
    'LIE': 'Liechtenstein',
    'MCO': 'Monaco',
    'MDA': 'Moldova, Republic of',
    'MKD': 'North Macedonia',
    'MNE': 'Montenegro, Republic of',
    'NOR': 'Norway',
    'SCG': 'Serbia, Republic of', #20
    'SHN': 'Saint Helena',
    'SJM': '', ## NA
    'SMR': 'San Marino',
    'SPM': 'Saint Pierre and Miquelon',
    'SRB': 'Serbia, Republic of',
    'TCA': 'Turks and Caicos Islands',
    'TUR': 'Turkey',
    'UKR': 'Ukraine',
    'VAT': 'Holy See (Vatican City State)',
    'WLF': 'Wallis and Futuna',#30
    'YUG': '', ## NA
}

Other_Asia_Pacific = {
    'AFG': 'Afghanistan',
    'ASM': 'American Samoa',
    'BGD': 'Bangladesh',
    'BRN': 'Brunei Darussalam',
    'BTN': 'Bhutan',
    'CCK': '', ## NA
    'COK': 'Cook Islands',
    'CXR': '', ## NA
    'FJI': 'Fiji',
    'FSM': 'Micronesia, Federated States of', #10
    'GUM': 'Guam',
    'IDN': 'Indonesia',
    'KAZ': 'Kazakhstan',
    'KGZ': 'Kyrgyzstan',
    'KHM': 'Cambodia',
    'KIR': 'Kiribati',
    'LAO': "Lao People's Democratic Republic",
    'LKA': 'Sri Lanka',
    'MDV': 'Maldives',
    'MHL': 'Marshall Islands', #20
    'MMR': 'Myanmar',
    'MNG': 'Mongolia',
    'MNP': 'Northen Mariana Islands',
    'MYS': 'Malaysia',
    'MYT': 'Mayotte',
    'NCL': 'New Caledonia',
    'NFK': '', ## NA
    'NIU': 'Niue',
    'NPL': 'Nepal',
    'NRU': 'Nauru', #30
    'NZL': 'New Zealand',
    'PAK': 'Pakistan',
    'PCI': '', ## NA
    'PCN': '', ## NA
    'PHL': 'Philippines',
    'PLW': 'Palau',
    'PNG': 'Papua New Guinea',
    'PRK': "Korea, Democratic People's Republic of",
    'PYF': 'French Polynesia',
    'SGP': 'Singapore', #40
    'SLB': 'Solomon Islands',
    'SYC': 'Seychelles',
    'THA': 'Thailand',
    'TJK': 'Tajikistan',
    'TKL': 'Tokelau',
    'TKM': 'Turkmenistan',
    'TLS': 'Timor-Leste',
    'TON': 'Tonga',
    'TUV': 'Tuvalu',
    'UZB': 'Uzbekistan', #50
    'VNM': 'Vietnam',
    'VUT': 'Vanuatu',
    'WSM': 'Samoa', #53
}

Other_Latin_America = {
    'ABW': 'Aruba',
    'AIA': 'Anguilla',
    'ANT': 'Netherlands Antilles',
    'ARG': 'Argentina',
    'ATG': 'Antigua and Barbuda',
    'BHS': 'Bahamas',
    'BLZ': 'Belize',
    'BMU': 'Bermuda',
    'BOL': 'Bolivia',
    'BRB': 'Barbados', #10
    'CHL': 'Chile',
    'COL': 'Colombia',
    'CRI': 'Costa Rica',
    'CUB': 'Cuba',
    'CYM': 'Cayman Islands',
    'DMA': 'Dominica',
    'DOM': 'Dominican Republic',
    'ECU': 'Ecuador',
    'FLK': 'Falkland Islands (Malvinas)',
    'GLP': 'Guadeloupe', #20
    'GRD': 'Grenada',
    'GTM': 'Guatemala',
    'GUF': 'French Guiana',
    'GUY': 'Guyana',
    'HND': 'Honduras',
    'HTI': 'Haiti',
    'JAM': 'Jamaica',
    'KNA': 'Saint Kitts and Nevis',
    'LCA': 'Saint Lucia',
    'MSR': 'Montserrat', #30
    'MTQ': 'Martinique',
    'NIC': 'Nicaragua',
    'PAN': 'Panama',
    'PER': 'Peru',
    'PRY': 'Paraguay',
    'SLV': 'El Salvador',
    'SUR': 'Suriname',
    'TTO': 'Trinidad and Tobago',
    'URY': 'Uruguay',
    'VCT': 'Saint Vincent and the Grenadines', #40
    'VEN': 'Venezuela',
    'VGB': 'Virgin Islands, British', # British Virgin Islands
    'VIR': 'virgin Islands, U.S.', #43
}

US = {'PRI': 'Puerto Rico',
      'USA': 'United States of America' #2
}

NA = {
    'BES': 'Bonaire, Sint Eustatius and Saba',
    'CUW': 'Curaçao',
    'BLM': 'Saint Barthélemy',
    'MAF': 'Saint Martin (French part)',
    'SXM': 'Sint Maarten (Dutch part)',
    'SSD': 'South Sudan' #6
}

# %%
Australia = {'AUS': 'Australia'}
Brazil = {'BRA': 'Brazil'}
Canada = {'CAN': 'Canada'}
India = {'IND': 'India'}
Japan = {'JPN': 'Japan'}
Mexico = {'MEX': 'Mexico'}
Russia = {'RUS': 'Russia'}
South_Korea = {'KOR': 'South Korea'}
World = {'WLD': 'Global'}
EU_28 = {'EU28': 'European Union (28 Countries)'}

# %%
print(Africa)
print(Australia)
print(Brazil)
print(Canada)
print(China)
print(EU_27)
print(EU_28)
print(India)
print(Japan)
print(Mexico)
print(Middle_East)
print(Non_EU_Europe)
print(Other_Asia_Pacific)
print(Other_Latin_America)
print(Russia)
print(South_Korea)
print(US)
print(World)
print(NA)
# Out:
# {'AGO': 'Angola', 'BDI': 'Burundi', 'BEN': 'Benin', 'BFA': 'Burkina Faso', 'BWA': 'Botswna', 'CAF': 'Central African Republic', 'CIV': "Cote d'lvoire", 'CMR': 'Cameroon', 'COD': 'Congo, The Democratic Republic Of The', 'COG': 'Congo, The Democratic Republic Of The', 'COM': 'Comoros', 'CPV': 'Cape Verde', 'DJI': 'Djibouti', 'DZA': 'Algeria', 'ERI': 'Eritrea', 'ESH': 'Western Sahara', 'ETH': 'Ethiopia', 'GAB': 'Gabon', 'GHA': 'Ghana', 'GIN': 'Guinea', 'GMB': 'Gambia', 'GNB': 'Guinea-Bissau', 'GNQ': 'Equatorial-Guinea', 'KEN': 'Kenya', 'LBR': 'Liberia', 'LBY': 'Libya', 'LSO': 'Lesotho', 'MAR': 'Morocco', 'MDG': 'Madagascar', 'MLI': 'Mali', 'MOZ': 'Mozambique', 'MRT': 'Mauritania', 'MUS': 'Mauritius', 'MWI': 'Malawi', 'NAM': 'Namibia', 'NER': 'Niger', 'NGA': 'Nigeria', 'REU': 'Reunion', 'RWA': 'Rwanda', 'SDN': 'Sudan', 'SEN': 'Senegal', 'SLE': 'Sierra Leone', 'SOM': 'Somalia', 'STP': 'Sao Tome and Principe', 'SWZ': 'Swaziland', 'TCD': 'Chad', 'TGO': 'Togo', 'TUN': 'Tunisia', 'TZA': 'Tanz
# ...
